# %%
import struct
import numpy as np
import colorsys
from keras.layers import Conv2D
from keras.layers import Input
from keras.layers import BatchNormalization
from keras.layers import LeakyReLU
from keras.layers import ZeroPadding2D
from keras.layers import UpSampling2D
from keras.layers.merge import add, concatenate
from keras.models import Model
from matplotlib import pyplot
from matplotlib.patches import Rectangle
from numpy import expand_dims
from keras.preprocessing.image import load_img, img_to_array
import cv2
import random
import os
import errno
import argparse
import numpy as np
import cv2
import tensorflow.compat.v1 as tf
import scipy.linalg
from scipy.optimize import linear_sum_assignment

# %%
def _conv_block(inp,convs,skip = True):
    x = inp
    count = 0
    for conv in convs:
        if count == (len(convs) - 2) and skip:
            skip_connection = x
        count += 1
        if conv['stride'] > 1:
            x = ZeroPadding2D(((1,0),(1,0)))(x)
        x = Conv2D(conv['filter'],conv['kernel'],strides=conv['stride'],
                   padding='valid' if conv['stride'] > 1 else 'same',
                   name='conv_' + str(conv['layer_idx']),
                   use_bias = False if conv['bnorm'] else True)(x)
        if conv['bnorm']: 
            x = BatchNormalization(epsilon=0.001, name='bnorm_' + str(conv['layer_idx']))(x)
        if conv['leaky']: 
            x = LeakyReLU(alpha=0.1, name='leaky_' + str(conv['layer_idx']))(x)
    return add([skip_connection, x]) if skip else x

# %%
def make_yolov3_model():
    input_image = Input(shape=(None, None, 3))

    x = _conv_block(input_image, [{'filter': 32, 'kernel': 3, 'stride': 1, 'bnorm': True, 'leaky': True, 'layer_idx': 0},
                                  {'filter': 64, 'kernel': 3, 'stride': 2, 'bnorm': True, 'leaky': True, 'layer_idx': 1},
                                  {'filter': 32, 'kernel': 1, 'stride': 1, 'bnorm': True, 'leaky': True, 'layer_idx': 2},
                                  {'filter': 64, 'kernel': 3, 'stride': 1, 'bnorm': True, 'leaky': True, 'layer_idx': 3}])

    x = _conv_block(x, [{'filter': 128, 'kernel': 3, 'stride': 2, 'bnorm': True, 'leaky': True, 'layer_idx': 5},
                        {'filter':  64, 'kernel': 1, 'stride': 1, 'bnorm': True, 'leaky': True, 'layer_idx': 6},
                        {'filter': 128, 'kernel': 3, 'stride': 1, 'bnorm': True, 'leaky': True, 'layer_idx': 7}])

    x = _conv_block(x, [{'filter':  64, 'kernel': 1, 'stride': 1, 'bnorm': True, 'leaky': True, 'layer_idx': 9},
                        {'filter': 128, 'kernel': 3, 'stride': 1, 'bnorm': True, 'leaky': True, 'layer_idx': 10}])
    
    x = _conv_block(x, [{'filter': 256, 'kernel': 3, 'stride': 2, 'bnorm': True, 'leaky': True, 'layer_idx': 12},
                        {'filter': 128, 'kernel': 1, 'stride': 1, 'bnorm': True, 'leaky': True, 'layer_idx': 13},
                        {'filter': 256, 'kernel': 3, 'stride': 1, 'bnorm': True, 'leaky': True, 'layer_idx': 14}])
    
    for i in range(7):
        x = _conv_block(x, [{'filter': 128, 'kernel': 1, 'stride': 1, 'bnorm': True, 'leaky': True, 'layer_idx': 16+i*3},
                            {'filter': 256, 'kernel': 3, 'stride': 1, 'bnorm': True, 'leaky': True, 'layer_idx': 17+i*3}])
    skip_36 = x

    x = _conv_block(x, [{'filter': 512, 'kernel': 3, 'stride': 2, 'bnorm': True, 'leaky': True, 'layer_idx': 37},
                        {'filter': 256, 'kernel': 1, 'stride': 1, 'bnorm': True, 'leaky': True, 'layer_idx': 38},
                        {'filter': 512, 'kernel': 3, 'stride': 1, 'bnorm': True, 'leaky': True, 'layer_idx': 39}])
    
    for i in range(7):
        x = _conv_block(x, [{'filter': 256, 'kernel': 1, 'stride': 1, 'bnorm': True, 'leaky': True, 'layer_idx': 41+i*3},
                            {'filter': 512, 'kernel': 3, 'stride': 1, 'bnorm': True, 'leaky': True, 'layer_idx': 42+i*3}])
    skip_61 = x
    
    x = _conv_block(x, [{'filter': 1024, 'kernel': 3, 'stride': 2, 'bnorm': True, 'leaky': True, 'layer_idx': 62},
                        {'filter':  512, 'kernel': 1, 'stride': 1, 'bnorm': True, 'leaky': True, 'layer_idx': 63},
                        {'filter': 1024, 'kernel': 3, 'stride': 1, 'bnorm': True, 'leaky': True, 'layer_idx': 64}])
   
    for i in range(3):
        x = _conv_block(x, [{'filter':  512, 'kernel': 1, 'stride': 1, 'bnorm': True, 'leaky': True, 'layer_idx': 66+i*3},
                            {'filter': 1024, 'kernel': 3, 'stride': 1, 'bnorm': True, 'leaky': True, 'layer_idx': 67+i*3}])
    
    x = _conv_block(x, [{'filter':  512, 'kernel': 1, 'stride': 1, 'bnorm': True, 'leaky': True, 'layer_idx': 75},
                        {'filter': 1024, 'kernel': 3, 'stride': 1, 'bnorm': True, 'leaky': True, 'layer_idx': 76},
                        {'filter':  512, 'kernel': 1, 'stride': 1, 'bnorm': True, 'leaky': True, 'layer_idx': 77},
                        {'filter': 1024, 'kernel': 3, 'stride': 1, 'bnorm': True, 'leaky': True, 'layer_idx': 78},
                        {'filter':  512, 'kernel': 1, 'stride': 1, 'bnorm': True, 'leaky': True, 'layer_idx': 79}], skip=False)
    
    yolo_82 = _conv_block(x, [{'filter': 1024, 'kernel': 3, 'stride': 1, 'bnorm': True,  'leaky': True,  'layer_idx': 80},
                              {'filter':  255, 'kernel': 1, 'stride': 1, 'bnorm': False, 'leaky': False, 'layer_idx': 81}], skip=False)
    
    x = _conv_block(x, [{'filter': 256, 'kernel': 1, 'stride': 1, 'bnorm': True, 'leaky': True, 'layer_idx': 84}], skip=False)
    x = UpSampling2D(2)(x)
    x = concatenate([x, skip_61])
    
    x = _conv_block(x, [{'filter': 256, 'kernel': 1, 'stride': 1, 'bnorm': True, 'leaky': True, 'layer_idx': 87},
                        {'filter': 512, 'kernel': 3, 'stride': 1, 'bnorm': True, 'leaky': True, 'layer_idx': 88},
                        {'filter': 256, 'kernel': 1, 'stride': 1, 'bnorm': True, 'leaky': True, 'layer_idx': 89},
                        {'filter': 512, 'kernel': 3, 'stride': 1, 'bnorm': True, 'leaky': True, 'layer_idx': 90},
                        {'filter': 256, 'kernel': 1, 'stride': 1, 'bnorm': True, 'leaky': True, 'layer_idx': 91}], skip=False)
    
    yolo_94 = _conv_block(x, [{'filter': 512, 'kernel': 3, 'stride': 1, 'bnorm': True,  'leaky': True,  'layer_idx': 92},
                              {'filter': 255, 'kernel': 1, 'stride': 1, 'bnorm': False, 'leaky': False, 'layer_idx': 93}], skip=False)
    
    x = _conv_block(x, [{'filter': 128, 'kernel': 1, 'stride': 1, 'bnorm': True, 'leaky': True,   'layer_idx': 96}], skip=False)
    x = UpSampling2D(2)(x)
    x = concatenate([x, skip_36])
    
    yolo_106 = _conv_block(x, [{'filter': 128, 'kernel': 1, 'stride': 1, 'bnorm': True,  'leaky': True,  'layer_idx': 99},
                               {'filter': 256, 'kernel': 3, 'stride': 1, 'bnorm': True,  'leaky': True,  'layer_idx': 100},
                               {'filter': 128, 'kernel': 1, 'stride': 1, 'bnorm': True,  'leaky': True,  'layer_idx': 101},
                               {'filter': 256, 'kernel': 3, 'stride': 1, 'bnorm': True,  'leaky': True,  'layer_idx': 102},
                               {'filter': 128, 'kernel': 1, 'stride': 1, 'bnorm': True,  'leaky': True,  'layer_idx': 103},
                               {'filter': 256, 'kernel': 3, 'stride': 1, 'bnorm': True,  'leaky': True,  'layer_idx': 104},
                               {'filter': 255, 'kernel': 1, 'stride': 1, 'bnorm': False, 'leaky': False, 'layer_idx': 105}], skip=False)
    model = Model(input_image, [yolo_82, yolo_94, yolo_106])
    return model

# %%
class WeightReader:
    def __init__(self, weight_file):
        with open(weight_file, 'rb') as w_f:
            major,	= struct.unpack('i', w_f.read(4))
            minor,	= struct.unpack('i', w_f.read(4))
            revision, = struct.unpack('i', w_f.read(4))
            if (major*10 + minor) >= 2 and major < 1000 and minor < 1000:
                w_f.read(8)
            else:
                w_f.read(4)
            transpose = (major > 1000) or (minor > 1000)
            binary = w_f.read()
        self.offset = 0
        self.all_weights = np.frombuffer(binary, dtype='float32')
 
    def read_bytes(self, size):
        self.offset = self.offset + size
        return self.all_weights[self.offset-size:self.offset]
    
    def load_weights(self, model):
        for i in range(106):
            try:
                conv_layer = model.get_layer('conv_' + str(i))
                print("loading weights of convolution #" + str(i))
                if i not in [81, 93, 105]:
                    norm_layer = model.get_layer('bnorm_' + str(i))
                    size = np.prod(norm_layer.get_weights()[0].shape)
                    beta  = self.read_bytes(size) # bias
                    gamma = self.read_bytes(size) # scale
                    mean  = self.read_bytes(size) # mean
                    var   = self.read_bytes(size) # variance
                    weights = norm_layer.set_weights([gamma, beta, mean, var])
                if len(conv_layer.get_weights()) > 1:
                    bias   = self.read_bytes(np.prod(conv_layer.get_weights()[1].shape))
                    kernel = self.read_bytes(np.prod(conv_layer.get_weights()[0].shape))
                    kernel = kernel.reshape(list(reversed(conv_layer.get_weights()[0].shape)))
                    kernel = kernel.transpose([2,3,1,0])
                    conv_layer.set_weights([kernel, bias])
                else:
                    kernel = self.read_bytes(np.prod(conv_layer.get_weights()[0].shape))
                    kernel = kernel.reshape(list(reversed(conv_layer.get_weights()[0].shape)))
                    kernel = kernel.transpose([2,3,1,0])
                    conv_layer.set_weights([kernel])
            except ValueError:
                print("no convolution #" + str(i))
    def reset(self):
        self.offset = 0

# %%
label_map = {
    "person": "blue",
    "bicycle": "yellow", 
    "car": "red",
    "truck": "green",
    "motorbike": "white", 
    "aeroplane": "white", 
    "bus": "white",
    "train": "white", 
    "boat": "white"
}

# %%
class BoundBox:
    def __init__(self, xmin, ymin, xmax, ymax, objness = None, classes = None):
        self.xmin = xmin
        self.ymin = ymin
        self.xmax = xmax
        self.ymax = ymax
        self.objness = objness
        self.classes = classes
        self.label = -1
        self.score = -1

    def get_label(self):
        if self.label == -1:
            self.label = np.argmax(self.classes)

        return self.label

    def get_score(self):
        if self.score == -1:
            self.score = self.classes[self.get_label()]
 
        return self.score

# %%
def _sigmoid(x):
    return 1. / (1. + np.exp(-x))

# %%
def decode_netout(netout, anchors, obj_thresh, net_h, net_w):
    grid_h, grid_w = netout.shape[:2]
    nb_box = 3
    netout = netout.reshape((grid_h, grid_w, nb_box, -1))
    nb_class = netout.shape[-1] - 5
    boxes = []
    netout[..., :2]  = _sigmoid(netout[..., :2])
    netout[..., 4:]  = _sigmoid(netout[..., 4:])
    netout[..., 5:]  = netout[..., 4][..., np.newaxis] * netout[..., 5:]
    netout[..., 5:] *= netout[..., 5:] > obj_thresh
 
    for i in range(grid_h*grid_w):
        row = i / grid_w
        col = i % grid_w
        for b in range(nb_box):
            
            objectness = netout[int(row)][int(col)][b][4]
            if(objectness.all() <= obj_thresh): continue
            
            x, y, w, h = netout[int(row)][int(col)][b][:4]
            x = (col + x) / grid_w 
            y = (row + y) / grid_h 
            w = anchors[2 * b + 0] * np.exp(w) / net_w 
            h = anchors[2 * b + 1] * np.exp(h) / net_h 
            
            classes = netout[int(row)][col][b][5:]
            box = BoundBox(x-w/2, y-h/2, x+w/2, y+h/2, objectness, classes)
            boxes.append(box)
    return boxes

# %%
def correct_yolo_boxes(boxes, image_h, image_w, net_h, net_w):
    new_w, new_h = net_w, net_h
    for i in range(len(boxes)):
        x_offset, x_scale = (net_w - new_w)/2./net_w, float(new_w)/net_w
        y_offset, y_scale = (net_h - new_h)/2./net_h, float(new_h)/net_h
        boxes[i].xmin = int((boxes[i].xmin - x_offset) / x_scale * image_w)
        boxes[i].xmax = int((boxes[i].xmax - x_offset) / x_scale * image_w)
        boxes[i].ymin = int((boxes[i].ymin - y_offset) / y_scale * image_h)
        boxes[i].ymax = int((boxes[i].ymax - y_offset) / y_scale * image_h)

# %%
def _interval_overlap(interval_a, interval_b):
    x1, x2 = interval_a
    x3, x4 = interval_b
    if x3 < x1:
        if x4 < x1:
            return 0
        else:
            return min(x2,x4) - x1
    else:
        if x2 < x3:
            return 0
        else:
            return min(x2,x4) - x3

# %%
def bbox_iou(box1, box2):
    intersect_w = _interval_overlap([box1.xmin, box1.xmax], [box2.xmin, box2.xmax])
    intersect_h = _interval_overlap([box1.ymin, box1.ymax], [box2.ymin, box2.ymax])
    intersect = intersect_w * intersect_h
    w1, h1 = box1.xmax-box1.xmin, box1.ymax-box1.ymin
    w2, h2 = box2.xmax-box2.xmin, box2.ymax-box2.ymin
    union = w1*h1 + w2*h2 - intersect
    return float(intersect) / union

# %%
def do_nms(boxes, nms_thresh):
    if len(boxes) > 0:
        nb_class = len(boxes[0].classes)
    else:
        return
    for c in range(nb_class):
        sorted_indices = np.argsort([-box.classes[c] for box in boxes])
        for i in range(len(sorted_indices)):
            index_i = sorted_indices[i]
            if boxes[index_i].classes[c] == 0: continue
            for j in range(i+1, len(sorted_indices)):
                index_j = sorted_indices[j]
                if bbox_iou(boxes[index_i], boxes[index_j]) >= nms_thresh:
                    boxes[index_j].classes[c] = 0

# %%
def load_image_pixels(filename, shape):
    
    image = load_img(filename)
    width, height = image.size
    
    image = load_img(filename, target_size=shape)
    
    image = img_to_array(image)
    
    image = image.astype('float32')
    image /= 255.0
    
    image = expand_dims(image, 0)
    return image, width, height

# %%
def image_preprocess(image, target_size):
    ih, iw    = target_size
    h,  w, _  = image.shape

    scale = min(iw/w, ih/h)
    nw, nh  = int(scale * w), int(scale * h)
    image_resized = cv2.resize(image, (nw, nh))

    image_paded = np.full(shape=[ih, iw, 3], fill_value=128.0)
    dw, dh = (iw - nw) // 2, (ih-nh) // 2
    image_paded[dh:nh+dh, dw:nw+dw, :] = image_resized
    image_paded = image_paded / 255.

    image_expanded = expand_dims(image_paded, 0)

    return image_expanded, w, h

# %%
def get_boxes(boxes, labels, thresh):
    v_boxes, v_labels, v_scores = list(), list(), list()
    
    for box in boxes:
        
        for i in range(len(labels)):
            
            if box.classes[i] > thresh:
                v_boxes.append(box)
                v_labels.append(labels[i])
                v_scores.append(box.classes[i]*100)
                
    return v_boxes, v_labels, v_scores

# %%
def draw_boxes(filename, v_boxes, v_labels, v_scores):
    
    data = pyplot.imread(filename)
    
    pyplot.imshow(data)
    
    ax = pyplot.gca()
    
    for i in range(len(v_boxes)):
        box = v_boxes[i]
    
        y1, x1, y2, x2 = box.ymin, box.xmin, box.ymax, box.xmax
    
        width, height = x2 - x1, y2 - y1
    
        rect = Rectangle((x1, y1), width, height, fill=False, color=label_map[v_labels[i]])
    
        ax.add_patch(rect)
    
        label = "%s (%.3f)" % (v_labels[i], v_scores[i])
        pyplot.text(x1, y1, label, color=label_map[v_labels[i]])
    
    pyplot.show()

# %%
def draw_bbox(image, bboxes, CLASSES, show_label=True, show_confidence = True, Text_colors=(255,255,0), rectangle_colors='', tracking=False):   
    NUM_CLASS = CLASSES
    num_classes = len(NUM_CLASS)
    image_h, image_w, _ = image.shape
    hsv_tuples = [(1.0 * x / num_classes, 1., 1.) for x in range(num_classes)]
    
    colors = list(map(lambda x: colorsys.hsv_to_rgb(*x), hsv_tuples))
    colors = list(map(lambda x: (int(x[0] * 255), int(x[1] * 255), int(x[2] * 255)), colors))

    random.seed(0)
    random.shuffle(colors)
    random.seed(None)
    
    for i, bbox in enumerate(bboxes):
        coor = np.array(bbox[:4], dtype=np.int32)
        score = bbox[4]
        class_ind = int(bbox[5])
        
        bbox_color = rectangle_colors if rectangle_colors != '' else colors[class_ind]
        bbox_thick = int(0.6 * (image_h + image_w) / 1000)
        
        if bbox_thick < 1: bbox_thick = 1
        fontScale = 0.75 * bbox_thick
        (x1, y1), (x2, y2) = (coor[0], coor[1]), (coor[2], coor[3])

        
        cv2.rectangle(image, (x1, y1), (x2, y2), bbox_color, bbox_thick*2)

        if show_label:
            
            score_str = " {:.2f}".format(score) if show_confidence else ""

            if tracking: score_str = " "+str(score)

            label = "{}".format(NUM_CLASS[class_ind]) + score_str

            
            (text_width, text_height), baseline = cv2.getTextSize(label, cv2.FONT_HERSHEY_COMPLEX_SMALL,
                                                                  fontScale, thickness=bbox_thick)
            
            cv2.rectangle(image, (x1, y1), (x1 + text_width, y1 - text_height - baseline), bbox_color, thickness=cv2.FILLED)
            
            cv2.putText(image, label, (x1, y1-4), cv2.FONT_HERSHEY_COMPLEX_SMALL,
                        fontScale, Text_colors, bbox_thick, lineType=cv2.LINE_AA)

    return image

# %%
NUM_CLASS = {
    0: 'person',
    1: 'bicycle',
    2: 'car',
    3: 'motorbike',
    4: 'aeroplane',
    5: 'bus',
    6: 'train',
    7: 'truck',
    8: 'boat',
    9: 'traffic-light',
    10: 'fire-hydrant',
    11: 'stop-sign',
    12: 'parking-meter',
    13: 'bench',
    14: 'bird',
    15: 'cat',
    16: 'dog',
    17: 'horse',
    18: 'sheep',
    19: 'cow',
    20: 'elephant',
    21: 'bear',
    22: 'zebra',
    23: 'giraffe',
    24: 'backpack',
    25: 'umbrella',
    26: 'handbag',
    27: 'tie',
    28: 'suitcase',
    29: 'frisbee',
    30: 'skis',
    31: 'snowboard',
    32: 'sports-ball',
    33: 'kite',
    34: 'baseball-bat',
    35: 'baseball-glove',
    36: 'skateboard',
    37: 'surfboard',
    38: 'tennis-racket',
    39: 'bottle',
    40: 'wine-glass',
    41: 'cup',
    42: 'fork',
    43: 'knife',
    44: 'spoon',
    45: 'bowl',
    46: 'banana',
    47: 'apple',
    48: 'sandwich',
    49: 'orange',
    50: 'broccoli',
    51: 'carrot',
    52: 'hot-dog',
    53: 'pizza',
    54: 'donut',
    55: 'cake',
    56: 'chair',
    57: 'sofa',
    58: 'pottedplant',
    59: 'bed',
    60: 'diningtable',
    61: 'toilet',
    62: 'tvmonitor',
    63: 'laptop',
    64: 'mouse',
    65: 'remote',
    66: 'keyboard',
    67: 'cell-phone',
    68: 'microwave',
    69: 'oven',
    70: 'toaster',
    71: 'sink',
    72: 'refrigerator',
    73: 'book',
    74: 'clock',
    75: 'vase',
    76: 'scissors',
    77: 'teddy-bear', 
    78: 'hair-drier',
    79: 'toothbrush'
}

# %%
# !wget https://pjreddie.com/media/files/yolov3.weights -O yolov3.weights
# Out:
# --2022-10-30 15:22:05--  https://pjreddie.com/media/files/yolov3.weights
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 248007048 (237M) [application/octet-stream]
# Saving to: ‘yolov3.weights’
#
# yolov3.weights      100%[===================>] 236.52M  20.7MB/s    in 12s
#
# 2022-10-30 15:22:18 (19.1 MB/s) - ‘yolov3.weights’ saved [248007048/248007048]

# %%
model = make_yolov3_model()


weight_reader = WeightReader('yolov3.weights')

weight_reader.load_weights(model)

model.save('model.h5')
# Out:
# 2022-10-30 15:22:18.904136: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-30 15:22:19.021016: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-30 15:22:19.021836: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-30 15:22:19.023558: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-10-30 15:22:19.023889: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-30 15:22:19.024651: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-30 15:22:19.025308: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-30 15:22:20.961495: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-30 15:22:20.962432: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-30 15:22:20.963164: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-30 15:22:20.963745: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15401 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# loading weights of convolution #0
# loading weights of convolution #1
# loading weights of convolution #2
# loading weights of convolution #3
# no convolution #4
# loading weights of convolution #5
# loading weights of convolution #6
# loading weights of convolution #7
# no convolution #8
# loading weights of convolution #9
# loading weights of convolution #10
# no convolution #11
# loading weights of convolution #12
# loading weights of convolution #13
# loading weights of convolution #14
# no convolution #15
# loading weights of convolution #16
# loading weights of convolution #17
# no convolution #18
# loading weights of convolution #19
# loading weights of convolution #20
# no convolution #21
# loading weights of convolution #22
# loading weights of convolution #23
# no convolution #24
# loading weights of convolution #25
# loading weights of convolution #26
# no convolution #27
# loading weights of convolution #28
# loading weights of convolution #29
# no convolution #30
# loading weights of convolution #31
# loading weights of convolution #32
# no convolution #33
# loading weights of convolution #34
# loading weights of convolution #35
# no convolution #36
# loading weights of convolution #37
# loading weights of convolution #38
# loading weights of convolution #39
# no convolution #40
# loading weights of convolution #41
# loading weights of convolution #42
# no convolution #43
# loading weights of convolution #44
# loading weights of convolution #45
# no convolution #46
# loading weights of convolution #47
# loading weights of convolution #48
# no convolution #49
# loading weights of convolution #50
# loading weights of convolution #51
# no convolution #52
# loading weights of convolution #53
# loading weights of convolution #54
# no convolution #55
# loading weights of convolution #56
# loading weights of convolution #57
# no convolution #58
# loading weights of convolution #59
# loading weights of convolution #60
# no convolution #61
# loading weights of convolution #62
# loading weights of convolution #63
# loading weights of convolution #64
# no convolution #65
# loading weights of convolution #66
# loading weights of convolution #67
# no convolution #68
# loading weights of convolution #69
# loading weights of convolution #70
# no convolution #71
# loading weights of convolution #72
# loading weights of convolution #73
# no convolution #74
# loading weights of convolution #75
# loading weights of convolution #76
# loading weights of convolution #77
# loading weights of convolution #78
# loading weights of convolution #79
# loading weights of convolution #80
# loading weights of convolution #81
# no convolution #82
# no convolution #83
# loading weights of convolution #84
# no convolution #85
# no convolution #86
# loading weights of convolution #87
# loading weights of convolution #88
# loading weights of convolution #89
# loading weights of convolution #90
# loading weights of convolution #91
# loading weights of convolution #92
# loading weights of convolution #93
# no convolution #94
# no convolution #95
# loading weights of convolution #96
# no convolution #97
# no convolution #98
# loading weights of convolution #99
# loading weights of convolution #100
# loading weights of convolution #101
# loading weights of convolution #102
# loading weights of convolution #103
# loading weights of convolution #104
# loading weights of convolution #105
# /opt/conda/lib/python3.7/site-packages/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)

# %%
from keras.models import load_model
model = load_model('model.h5')

# %%
anchors = [[116,90, 156,198, 373,326], [30,61, 62,45, 59,119], [10,13, 16,30, 33,23]]

WIDTH, HEIGHT = 416, 416

class_threshold = 0.9

# %%
class Detection(object):
    def __init__(self, tlwh, confidence, class_name, feature):
        self.tlwh = np.asarray(tlwh, dtype=np.float)
        self.confidence = float(confidence)
        self.class_name = class_name
        self.feature = np.asarray(feature, dtype=np.float32)

    def get_class(self):
        return self.class_name

    def to_tlbr(self):
        ret = self.tlwh.copy()
        ret[2:] += ret[:2]
        return ret

    def to_xyah(self):
        ret = self.tlwh.copy()
        ret[:2] += ret[2:] / 2
        ret[2] /= ret[3]
        return ret

# %%
class ImageEncoder(object):

    def __init__(self, checkpoint_filename, input_name="images", output_name="features"):
        self.session = tf.Session()
        with tf.gfile.GFile(checkpoint_filename, "rb") as file_handle:
            graph_def = tf.GraphDef()
            graph_def.ParseFromString(file_handle.read())
        tf.import_graph_def(graph_def)
        try:
            self.input_var = tf.get_default_graph().get_tensor_by_name(input_name)
            self.output_var = tf.get_default_graph().get_tensor_by_name(output_name)
        except KeyError:
            layers = [i.name for i in tf.get_default_graph().get_operations()]
            self.input_var = tf.get_default_graph().get_tensor_by_name(layers[0]+':0')
            self.output_var = tf.get_default_graph().get_tensor_by_name(layers[-1]+':0')            

        assert len(self.output_var.get_shape()) == 2
        assert len(self.input_var.get_shape()) == 4
        self.feature_dim = self.output_var.get_shape().as_list()[-1]
        self.image_shape = self.input_var.get_shape().as_list()[1:]

    def __call__(self, data_x, batch_size=32):
        out = np.zeros((len(data_x), self.feature_dim), np.float32)
        _run_in_batches(
            lambda x: self.session.run(self.output_var, feed_dict=x),
            {self.input_var: data_x}, out, batch_size)
        return out

# %%
def _run_in_batches(f, data_dict, out, batch_size):
    data_len = len(out)
    num_batches = int(data_len / batch_size)

    s, e = 0, 0
    for i in range(num_batches):
        s, e = i * batch_size, (i + 1) * batch_size
        batch_data_dict = {k: v[s:e] for k, v in data_dict.items()}
        out[s:e] = f(batch_data_dict)
    if e < len(out):
        batch_data_dict = {k: v[e:] for k, v in data_dict.items()}
        out[e:] = f(batch_data_dict)

# %%
def extract_image_patch(image, bbox, patch_shape):
    bbox = np.array(bbox)
    if patch_shape is not None:
        # correct aspect ratio to patch shape
        target_aspect = float(patch_shape[1]) / patch_shape[0]
        new_width = target_aspect * bbox[3]
        bbox[0] -= (new_width - bbox[2]) / 2
        bbox[2] = new_width

    # convert to top left, bottom right
    bbox[2:] += bbox[:2]
    bbox = bbox.astype(np.int)

    # clip at image boundaries
    bbox[:2] = np.maximum(0, bbox[:2])
    bbox[2:] = np.minimum(np.asarray(image.shape[:2][::-1]) - 1, bbox[2:])
    if np.any(bbox[:2] >= bbox[2:]):
        return None
    sx, sy, ex, ey = bbox
    image = image[sy:ey, sx:ex]
    image = cv2.resize(image, tuple(patch_shape[::-1]))
    return image

# %%
def create_box_encoder(model_filename, input_name="images:0", output_name="features:0", batch_size=32):
    image_encoder = ImageEncoder(model_filename, input_name, output_name)
    image_shape = image_encoder.image_shape

    def encoder(image, boxes):
        image_patches = []
        for box in boxes:
            patch = extract_image_patch(image, box, image_shape[:2])
            if patch is None:
                print("WARNING: Failed to extract image patch: %s." % str(box))
                patch = np.random.uniform(0., 255., image_shape).astype(np.uint8)
            image_patches.append(patch)
        image_patches = np.asarray(image_patches)
        return image_encoder(image_patches, batch_size)

    return encoder

# %%
def generate_detections(encoder, mot_dir, output_dir, detection_dir=None):
    if detection_dir is None:
        detection_dir = mot_dir
    try:
        os.makedirs(output_dir)
    except OSError as exception:
        if exception.errno == errno.EEXIST and os.path.isdir(output_dir):
            pass
        else:
            raise ValueError(
                "Failed to created output directory '%s'" % output_dir)

    for sequence in os.listdir(mot_dir):
        print("Processing %s" % sequence)
        sequence_dir = os.path.join(mot_dir, sequence)

        image_dir = os.path.join(sequence_dir, "img1")
        image_filenames = {
            int(os.path.splitext(f)[0]): os.path.join(image_dir, f)
            for f in os.listdir(image_dir)}

        detection_file = os.path.join(
            detection_dir, sequence, "det/det.txt")
        detections_in = np.loadtxt(detection_file, delimiter=',')
        detections_out = []

        frame_indices = detections_in[:, 0].astype(np.int)
        min_frame_idx = frame_indices.astype(np.int).min()
        max_frame_idx = frame_indices.astype(np.int).max()
        for frame_idx in range(min_frame_idx, max_frame_idx + 1):
            print("Frame %05d/%05d" % (frame_idx, max_frame_idx))
            mask = frame_indices == frame_idx
            rows = detections_in[mask]

            if frame_idx not in image_filenames:
                print("WARNING could not find image for frame %d" % frame_idx)
                continue
            bgr_image = cv2.imread(
                image_filenames[frame_idx], cv2.IMREAD_COLOR)
            features = encoder(bgr_image, rows[:, 2:6].copy())
            detections_out += [np.r_[(row, feature)] for row, feature
                               in zip(rows, features)]

        output_filename = os.path.join(output_dir, "%s.npy" % sequence)
        np.save(
            output_filename, np.asarray(detections_out), allow_pickle=False)

# %%
# !wget https://github.com/anushkadhiman/ObjectTracking-DeepSORT-YOLOv3-TF2/raw/master/model_data/coco/mars-small128.pb
# Out:
# --2022-10-30 15:22:27--  https://github.com/anushkadhiman/ObjectTracking-DeepSORT-YOLOv3-TF2/raw/master/model_data/coco/mars-small128.pb
# Resolving github.com (github.com)... 140.82.114.3
# Connecting to github.com (github.com)|140.82.114.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/anushkadhiman/ObjectTracking-DeepSORT-YOLOv3-TF2/master/model_data/coco/mars-small128.pb [following]
# --2022-10-30 15:22:28--  https://raw.githubusercontent.com/anushkadhiman/ObjectTracking-DeepSORT-YOLOv3-TF2/master/model_data/coco/mars-small128.pb
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.110.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 11244842 (11M) [application/octet-stream]
# Saving to: ‘mars-small128.pb’
#
# mars-small128.pb    100%[===================>]  10.72M  --.-KB/s    in 0.07s
#
# 2022-10-30 15:22:29 (147 MB/s) - ‘mars-small128.pb’ saved [11244842/11244842]

# %%
chi2inv95 = {
    1: 3.8415,
    2: 5.9915,
    3: 7.8147,
    4: 9.4877,
    5: 11.070,
    6: 12.592,
    7: 14.067,
    8: 15.507,
    9: 16.919}

# %%
class KalmanFilter(object):
    def __init__(self):
        ndim, dt = 4, 1.

        self._motion_mat = np.eye(2 * ndim, 2 * ndim)
        for i in range(ndim):
            self._motion_mat[i, ndim + i] = dt
        self._update_mat = np.eye(ndim, 2 * ndim)

        self._std_weight_position = 1. / 20
        self._std_weight_velocity = 1. / 160
        
    def initiate(self, measurement):
        mean_pos = measurement
        mean_vel = np.zeros_like(mean_pos)
        mean = np.r_[mean_pos, mean_vel]

        std = [
            2 * self._std_weight_position * measurement[3],
            2 * self._std_weight_position * measurement[3],
            1e-2,
            2 * self._std_weight_position * measurement[3],
            10 * self._std_weight_velocity * measurement[3],
            10 * self._std_weight_velocity * measurement[3],
            1e-5,
            10 * self._std_weight_velocity * measurement[3]]
        covariance = np.diag(np.square(std))
        return mean, covariance
    
    def predict(self, mean, covariance):
        std_pos = [
            self._std_weight_position * mean[3],
            self._std_weight_position * mean[3],
            1e-2,
            self._std_weight_position * mean[3]]
        std_vel = [
            self._std_weight_velocity * mean[3],
            self._std_weight_velocity * mean[3],
            1e-5,
            self._std_weight_velocity * mean[3]]
        motion_cov = np.diag(np.square(np.r_[std_pos, std_vel]))

        mean = np.dot(self._motion_mat, mean)
        covariance = np.linalg.multi_dot((
            self._motion_mat, covariance, self._motion_mat.T)) + motion_cov

        return mean, covariance
    
    def project(self, mean, covariance):
        std = [
            self._std_weight_position * mean[3],
            self._std_weight_position * mean[3],
            1e-1,
            self._std_weight_position * mean[3]]
        innovation_cov = np.diag(np.square(std))

        mean = np.dot(self._update_mat, mean)
        covariance = np.linalg.multi_dot((
            self._update_mat, covariance, self._update_mat.T))
        return mean, covariance + innovation_cov
    
    def update(self, mean, covariance, measurement):
        projected_mean, projected_cov = self.project(mean, covariance)

        chol_factor, lower = scipy.linalg.cho_factor(
            projected_cov, lower=True, check_finite=False)
        kalman_gain = scipy.linalg.cho_solve(
            (chol_factor, lower), np.dot(covariance, self._update_mat.T).T,
            check_finite=False).T
        innovation = measurement - projected_mean

        new_mean = mean + np.dot(innovation, kalman_gain.T)
        new_covariance = covariance - np.linalg.multi_dot((
            kalman_gain, projected_cov, kalman_gain.T))
        return new_mean, new_covariance
    
    def gating_distance(self, mean, covariance, measurements,only_position=False):
        mean, covariance = self.project(mean, covariance)
        if only_position:
            mean, covariance = mean[:2], covariance[:2, :2]
            measurements = measurements[:, :2]

        cholesky_factor = np.linalg.cholesky(covariance)
        d = measurements - mean
        z = scipy.linalg.solve_triangular(
            cholesky_factor, d.T, lower=True, check_finite=False,
            overwrite_b=True)
        squared_maha = np.sum(z * z, axis=0)
        return squared_maha

# %%
INFTY_COST = 1e+5


def min_cost_matching(distance_metric, max_distance, tracks, detections, track_indices=None,detection_indices=None):
    if track_indices is None:
        track_indices = np.arange(len(tracks))
    if detection_indices is None:
        detection_indices = np.arange(len(detections))

    if len(detection_indices) == 0 or len(track_indices) == 0:
        return [], track_indices, detection_indices  # Nothing to match.

    cost_matrix = distance_metric(
        tracks, detections, track_indices, detection_indices)
    cost_matrix[cost_matrix > max_distance] = max_distance + 1e-5
    indices = linear_sum_assignment(cost_matrix)
    indices = np.asarray(indices)
    indices = np.transpose(indices)
    matches, unmatched_tracks, unmatched_detections = [], [], []
    for col, detection_idx in enumerate(detection_indices):
        if col not in indices[:, 1]:
            unmatched_detections.append(detection_idx)
    for row, track_idx in enumerate(track_indices):
        if row not in indices[:, 0]:
            unmatched_tracks.append(track_idx)
    for row, col in indices:
        track_idx = track_indices[row]
        detection_idx = detection_indices[col]
        if cost_matrix[row, col] > max_distance:
            unmatched_tracks.append(track_idx)
            unmatched_detections.append(detection_idx)
        else:
            matches.append((track_idx, detection_idx))
    return matches, unmatched_tracks, unmatched_detections

# %%
def matching_cascade(
        distance_metric, max_distance, cascade_depth, tracks, detections,
        track_indices=None, detection_indices=None):
    if track_indices is None:
        track_indices = list(range(len(tracks)))
    if detection_indices is None:
        detection_indices = list(range(len(detections)))

    unmatched_detections = detection_indices
    matches = []
    for level in range(cascade_depth):
        if len(unmatched_detections) == 0:  # No detections left
            break

        track_indices_l = [
            k for k in track_indices
            if tracks[k].time_since_update == 1 + level
        ]
        if len(track_indices_l) == 0:  # Nothing to match at this level
            continue

        matches_l, _, unmatched_detections = \
            min_cost_matching(
                distance_metric, max_distance, tracks, detections,
                track_indices_l, unmatched_detections)
        matches += matches_l
    unmatched_tracks = list(set(track_indices) - set(k for k, _ in matches))
    return matches, unmatched_tracks, unmatched_detections

# %%
def gate_cost_matrix(
        kf, cost_matrix, tracks, detections, track_indices, detection_indices,
        gated_cost=INFTY_COST, only_position=False):
    gating_dim = 2 if only_position else 4
    gating_threshold = chi2inv95[gating_dim]
    measurements = np.asarray(
        [detections[i].to_xyah() for i in detection_indices])
    for row, track_idx in enumerate(track_indices):
        track = tracks[track_idx]
        gating_distance = kf.gating_distance(
            track.mean, track.covariance, measurements, only_position)
        cost_matrix[row, gating_distance > gating_threshold] = gated_cost
    return cost_matrix

# %%
def iou(bbox, candidates):
    bbox_tl, bbox_br = bbox[:2], bbox[:2] + bbox[2:]
    candidates_tl = candidates[:, :2]
    candidates_br = candidates[:, :2] + candidates[:, 2:]

    tl = np.c_[np.maximum(bbox_tl[0], candidates_tl[:, 0])[:, np.newaxis],
               np.maximum(bbox_tl[1], candidates_tl[:, 1])[:, np.newaxis]]
    br = np.c_[np.minimum(bbox_br[0], candidates_br[:, 0])[:, np.newaxis],
               np.minimum(bbox_br[1], candidates_br[:, 1])[:, np.newaxis]]
    wh = np.maximum(0., br - tl)

    area_intersection = wh.prod(axis=1)
    area_bbox = bbox[2:].prod()
    area_candidates = candidates[:, 2:].prod(axis=1)
    return area_intersection / (area_bbox + area_candidates - area_intersection)

# %%
def iou_cost(tracks, detections, track_indices=None,
             detection_indices=None):
    if track_indices is None:
        track_indices = np.arange(len(tracks))
    if detection_indices is None:
        detection_indices = np.arange(len(detections))

    cost_matrix = np.zeros((len(track_indices), len(detection_indices)))
    for row, track_idx in enumerate(track_indices):
        if tracks[track_idx].time_since_update > 1:
            cost_matrix[row, :] = linear_assignment.INFTY_COST
            continue

        bbox = tracks[track_idx].to_tlwh()
        candidates = np.asarray([detections[i].tlwh for i in detection_indices])
        cost_matrix[row, :] = 1. - iou(bbox, candidates)
    return cost_matrix

# %%
def non_max_suppression(boxes, classes, max_bbox_overlap, scores=None):
    if len(boxes) == 0:
        return []

    boxes = boxes.astype(np.float)
    pick = []

    x1 = boxes[:, 0]
    y1 = boxes[:, 1]
    x2 = boxes[:, 2] + boxes[:, 0]
    y2 = boxes[:, 3] + boxes[:, 1]

    area = (x2 - x1 + 1) * (y2 - y1 + 1)
    if scores is not None:
        idxs = np.argsort(scores)
    else:
        idxs = np.argsort(y2)

    while len(idxs) > 0:
        last = len(idxs) - 1
        i = idxs[last]
        pick.append(i)

        xx1 = np.maximum(x1[i], x1[idxs[:last]])
        yy1 = np.maximum(y1[i], y1[idxs[:last]])
        xx2 = np.minimum(x2[i], x2[idxs[:last]])
        yy2 = np.minimum(y2[i], y2[idxs[:last]])

        w = np.maximum(0, xx2 - xx1 + 1)
        h = np.maximum(0, yy2 - yy1 + 1)

        overlap = (w * h) / area[idxs[:last]]
        
        idxs = np.delete(
            idxs, np.concatenate(
                ([last], np.where(overlap > max_bbox_overlap)[0])))

    return pick

# %%
def _pdist(a, b):
    a, b = np.asarray(a), np.asarray(b)
    if len(a) == 0 or len(b) == 0:
        return np.zeros((len(a), len(b)))
    a2, b2 = np.square(a).sum(axis=1), np.square(b).sum(axis=1)
    r2 = -2. * np.dot(a, b.T) + a2[:, None] + b2[None, :]
    r2 = np.clip(r2, 0., float(np.inf))
    return r2

# %%
def _cosine_distance(a, b, data_is_normalized=False):
    if not data_is_normalized:
        a = np.asarray(a) / np.linalg.norm(a, axis=1, keepdims=True)
        b = np.asarray(b) / np.linalg.norm(b, axis=1, keepdims=True)
    return 1. - np.dot(a, b.T)

# %%
def _nn_euclidean_distance(x, y):
    distances = _pdist(x, y)
    return np.maximum(0.0, distances.min(axis=0))

# %%
def _nn_cosine_distance(x, y):
    distances = _cosine_distance(x, y)
    return distances.min(axis=0)

# %%
class NearestNeighborDistanceMetric(object):
    def __init__(self, metric, matching_threshold, budget=None):
        if metric == "euclidean":
            self._metric = _nn_euclidean_distance
        elif metric == "cosine":
            self._metric = _nn_cosine_distance
        else:
            raise ValueError(
                "Invalid metric; must be either 'euclidean' or 'cosine'")
        self.matching_threshold = matching_threshold
        self.budget = budget
        self.samples = {}
    
    def partial_fit(self, features, targets, active_targets):
        for feature, target in zip(features, targets):
            self.samples.setdefault(target, []).append(feature)
            if self.budget is not None:
                self.samples[target] = self.samples[target][-self.budget:]
        self.samples = {k: self.samples[k] for k in active_targets}
        
    def distance(self, features, targets):
        cost_matrix = np.zeros((len(targets), len(features)))
        for i, target in enumerate(targets):
            cost_matrix[i, :] = self._metric(self.samples[target], features)
        return cost_matrix

# %%
class TrackState:
    Tentative = 1
    Confirmed = 2
    Deleted = 3

# %%
class Track:
    def __init__(self, mean, covariance, track_id, n_init, max_age,
                 feature=None, class_name=None):
        self.mean = mean
        self.covariance = covariance
        self.track_id = track_id
        self.hits = 1
        self.age = 1
        self.time_since_update = 0

        self.state = TrackState.Tentative
        self.features = []
        if feature is not None:
            self.features.append(feature)

        self._n_init = n_init
        self._max_age = max_age
        self.class_name = class_name
    
    def to_tlwh(self):
        ret = self.mean[:4].copy()
        ret[2] *= ret[3]
        ret[:2] -= ret[2:] / 2
        return ret
    
    def to_tlbr(self):
        ret = self.to_tlwh()
        ret[2:] = ret[:2] + ret[2:]
        return ret
    
    def get_class(self):
        return self.class_name

    def predict(self, kf):
        self.mean, self.covariance = kf.predict(self.mean, self.covariance)
        self.age += 1
        self.time_since_update += 1
    
    def update(self, kf, detection):
        self.mean, self.covariance = kf.update(
            self.mean, self.covariance, detection.to_xyah())
        self.features.append(detection.feature)

        self.hits += 1
        self.time_since_update = 0
        if self.state == TrackState.Tentative and self.hits >= self._n_init:
            self.state = TrackState.Confirmed
    
    def mark_missed(self):
        if self.state == TrackState.Tentative:
            self.state = TrackState.Deleted
        elif self.time_since_update > self._max_age:
            self.state = TrackState.Deleted

    def is_tentative(self):
        return self.state == TrackState.Tentative

    def is_confirmed(self):
        return self.state == TrackState.Confirmed

    def is_deleted(self):
        return self.state == TrackState.Deleted

# %%
class Tracker:
    def __init__(self, metric, max_iou_distance=0.7, max_age=30, n_init=3):
        self.metric = metric
        self.max_iou_distance = max_iou_distance
        self.max_age = max_age
        self.n_init = n_init

        self.kf = KalmanFilter()
        self.tracks = []
        self._next_id = 1
    
    def predict(self):
        for track in self.tracks:
            track.predict(self.kf)
    
    def update(self, detections):
        matches, unmatched_tracks, unmatched_detections = \
            self._match(detections)

        
        for track_idx, detection_idx in matches:
            self.tracks[track_idx].update(
                self.kf, detections[detection_idx])
        for track_idx in unmatched_tracks:
            self.tracks[track_idx].mark_missed()
        for detection_idx in unmatched_detections:
            self._initiate_track(detections[detection_idx])
        self.tracks = [t for t in self.tracks if not t.is_deleted()]

        active_targets = [t.track_id for t in self.tracks if t.is_confirmed()]
        features, targets = [], []
        for track in self.tracks:
            if not track.is_confirmed():
                continue
            features += track.features
            targets += [track.track_id for _ in track.features]
            track.features = []
        self.metric.partial_fit(
            np.asarray(features), np.asarray(targets), active_targets)
    
    def _match(self, detections):

        def gated_metric(tracks, dets, track_indices, detection_indices):
            features = np.array([dets[i].feature for i in detection_indices])
            targets = np.array([tracks[i].track_id for i in track_indices])
            cost_matrix = self.metric.distance(features, targets)
            cost_matrix = gate_cost_matrix(
                self.kf, cost_matrix, tracks, dets, track_indices,
                detection_indices)

            return cost_matrix
        
        confirmed_tracks = [
            i for i, t in enumerate(self.tracks) if t.is_confirmed()]
        unconfirmed_tracks = [
            i for i, t in enumerate(self.tracks) if not t.is_confirmed()]

        matches_a, unmatched_tracks_a, unmatched_detections = \
                matching_cascade(
                gated_metric, self.metric.matching_threshold, self.max_age,
                self.tracks, detections, confirmed_tracks)


        iou_track_candidates = unconfirmed_tracks + [
            k for k in unmatched_tracks_a if
            self.tracks[k].time_since_update == 1]
        unmatched_tracks_a = [
            k for k in unmatched_tracks_a if
            self.tracks[k].time_since_update != 1]
        matches_b, unmatched_tracks_b, unmatched_detections = \
                min_cost_matching(
                iou_cost, self.max_iou_distance, self.tracks,
                detections, iou_track_candidates, unmatched_detections)

        matches = matches_a + matches_b
        unmatched_tracks = list(set(unmatched_tracks_a + unmatched_tracks_b))
        return matches, unmatched_tracks, unmatched_detections
    
    def _initiate_track(self, detection):
        mean, covariance = self.kf.initiate(detection.to_xyah())
        class_name = detection.get_class()
        self.tracks.append(Track(
            mean, covariance, self._next_id, self.n_init, self.max_age,
            detection.feature, class_name))
        self._next_id += 1

# %%
max_cosine_distance = 0.7
max_euclidean_distance = 0.7
nn_budget = None
model_filename = 'mars-small128.pb'

key_list = list(NUM_CLASS.keys()) 
val_list = list(NUM_CLASS.values())

# %%
import time

def object_tracking(video_path, output_path):
    encoder = create_box_encoder(model_filename, batch_size=1)
    metric = NearestNeighborDistanceMetric("cosine", max_cosine_distance, nn_budget)
    tracker = Tracker(metric)
    
    times, times_2 = [], []
    vid = cv2.VideoCapture(video_path)

    width = int(vid.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(vid.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fps = int(vid.get(cv2.CAP_PROP_FPS))
    codec = cv2.VideoWriter_fourcc(*'XVID')
    out = cv2.VideoWriter(output_path, codec, fps, (width, height))
    
    while True:
        _, frame = vid.read()
        
        try:
            original_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            original_frame = cv2.cvtColor(original_frame, cv2.COLOR_BGR2RGB)
        except:
            break

        image_data, image_w, image_h = image_preprocess(np.copy(original_frame), (WIDTH, HEIGHT))

        t1 = time.time()
        yhat = model.predict(image_data)

        boxes = list()
        for i in range(len(yhat)):
            boxes += decode_netout(yhat[i][0], anchors[i], class_threshold, HEIGHT, WIDTH)
        
        correct_yolo_boxes(boxes, image_h, image_w, HEIGHT, WIDTH)


        do_nms(boxes, 0.3)

        
        labels = ["person", "bicycle", "car", "motorbike", "aeroplane", "bus", "train", "truck","boat"]

        v_boxes, v_labels, v_scores = get_boxes(boxes, labels, class_threshold)

        t2 = time.time()
        
        boxes = []
        names = []
        scores = []
        for box, label, score in zip(v_boxes, v_labels, v_scores):
            boxes.append([
                 box.xmin, box.ymin, 
                (box.xmax - box.xmin), (box.ymax - box.ymin) * 2])
            names.append(label)
            scores.append(score)

        boxes = np.array(boxes) 
        names = np.array(names)
        scores = np.array(scores)
        features = np.array(encoder(original_frame, boxes))
        detections = [Detection(bbox, score, class_name, feature) for bbox, score, class_name, feature in zip(boxes, scores, names, features)]

        tracker.predict()
        tracker.update(detections)
        
        tracked_bboxes = []
        for track in tracker.tracks:
            if not track.is_confirmed() or track.time_since_update > 5:
                continue 
            bbox = track.to_tlbr()
            class_name = track.get_class() 
            tracking_id = track.track_id 
            index = key_list[val_list.index(class_name)] 
            tracked_bboxes.append(bbox.tolist() + [tracking_id, index])

        image = draw_bbox(original_frame, tracked_bboxes, CLASSES=NUM_CLASS, tracking=True)

        t3 = time.time()
        times.append(t2-t1)
        times_2.append(t3-t1)

        times = times[-20:]
        times_2 = times_2[-20:]

        ms = sum(times)/len(times)*1000
        fps = 1000 / ms
        fps2 = 1000 / (sum(times_2)/len(times_2)*1000)
        
        image = cv2.putText(image, "Time: {:.1f} FPS".format(fps), (0, 30), cv2.FONT_HERSHEY_COMPLEX_SMALL, 1, (0, 0, 255), 2)

        

        print("Time: {:.2f}ms, Detection FPS: {:.1f}, total FPS: {:.1f}".format(ms, fps, fps2))
        out.write(image)

    out.release()
    vid.release()

# %%
import os

VIDEO_PATH = '../input/kittiroadsegmentation/testing/'
videos = os.listdir(VIDEO_PATH)

for video in videos:
    print(f"Processing video {video}")
    object_tracking(VIDEO_PATH + video, video)
# Out:
# Processing video challenge.mp4
# 2022-10-30 15:22:47.784264: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-30 15:22:47.785439: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-30 15:22:47.786112: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-30 15:22:47.786706: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-30 15:22:47.787363: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-30 15:22:47.787790: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15401 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# OpenCV: FFMPEG: tag 0x44495658/'XVID' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 2022-10-30 15:22:48.087419: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# 2022-10-30 15:22:50.089335: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:12: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   if sys.path[0] == "":
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   This is separate from the ipykernel package so we can avoid doing imports until
# Time: 13923.58ms, Detection FPS: 0.1, total FPS: 0.1
# Time: 8299.68ms, Detection FPS: 0.1, total FPS: 0.1
# Time: 6402.54ms, Detection FPS: 0.2, total FPS: 0.2
# Time: 5377.91ms, Detection FPS: 0.2, total FPS: 0.2
# Time: 4914.06ms, Detection FPS: 0.2, total FPS: 0.2
# Time: 4490.54ms, Detection FPS: 0.2, total FPS: 0.2
# Time: 4232.83ms, Detection FPS: 0.2, total FPS: 0.2
# Time: 3994.15ms, Detection FPS: 0.3, total FPS: 0.2
# Time: 3814.59ms, Detection FPS: 0.3, total FPS: 0.3
# Time: 3672.76ms, Detection FPS: 0.3, total FPS: 0.3
# Time: 3567.62ms, Detection FPS: 0.3, total FPS: 0.3
# Time: 3476.77ms, Detection FPS: 0.3, total FPS: 0.3
# Time: 3387.70ms, Detection FPS: 0.3, total FPS: 0.3
# Time: 3316.27ms, Detection FPS: 0.3, total FPS: 0.3
# Time: 3249.76ms, Detection FPS: 0.3, total FPS: 0.3
# Time: 3223.15ms, Detection FPS: 0.3, total FPS: 0.3
# Time: 3200.73ms, Detection FPS: 0.3, total FPS: 0.3
# Time: 3161.76ms, Detection FPS: 0.3, total FPS: 0.3
# Time: 3119.79ms, Detection FPS: 0.3, total FPS: 0.3
# Time: 3097.05ms, Detection FPS: 0.3, total FPS: 0.3
# Time: 2520.42ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2506.80ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2493.27ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2495.67ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2471.02ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2471.91ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2454.75ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2455.81ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2478.51ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2510.60ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2502.19ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2495.76ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2513.07ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2510.72ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2514.76ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2494.24ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2470.79ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2476.58ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2478.29ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2462.09ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2459.34ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2493.08ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2508.81ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2508.28ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2497.90ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2509.88ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2511.55ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2523.57ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2506.33ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2483.38ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2491.13ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2492.10ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2477.96ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2476.83ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2522.66ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2526.64ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2527.26ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2512.61ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2526.94ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2528.21ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2528.64ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2491.63ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2481.17ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2491.34ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2491.30ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2478.10ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2494.85ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2507.33ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2501.98ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2499.50ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2491.90ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2507.02ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2509.95ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2509.68ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2463.13ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2455.53ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2467.72ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2469.81ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2451.91ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2485.29ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2501.59ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2503.89ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2510.71ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2502.65ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2521.79ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2522.33ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2505.13ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2482.08ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2492.01ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2487.07ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2489.76ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2508.81ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2506.59ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2525.20ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2528.43ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2538.03ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2532.18ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2548.40ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2551.49ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2520.31ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2505.54ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2521.00ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2512.09ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2527.15ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2526.67ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2542.54ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2545.26ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2545.30ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2533.95ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2538.62ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2550.93ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2517.03ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2515.85ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2501.05ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2515.09ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2510.56ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2534.17ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2517.94ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2533.62ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2533.63ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2531.14ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2514.67ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2521.52ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2518.24ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2500.99ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2483.82ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2479.87ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2496.26ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2527.76ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2517.96ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2506.04ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2518.21ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2517.63ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2515.94ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2499.36ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2493.71ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2484.27ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2484.82ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2467.65ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2463.81ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2481.88ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2528.74ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2523.19ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2508.47ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2525.57ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2525.33ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2527.74ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2510.29ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2477.04ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2496.28ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2490.80ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2474.96ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2471.89ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2518.42ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2515.80ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2517.13ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2493.15ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2509.55ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2508.38ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2507.79ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2489.11ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2441.50ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2453.18ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2462.72ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2444.93ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2447.56ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2498.24ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2499.41ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2501.51ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2484.19ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2501.03ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2502.64ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2504.71ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2459.08ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2460.66ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2477.17ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2489.59ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2474.99ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2512.97ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2532.52ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2533.55ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2534.36ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2518.73ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2526.59ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2526.34ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2526.93ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2474.11ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2472.96ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2488.86ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2506.99ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2492.53ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2524.98ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2541.92ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2544.76ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2542.81ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2526.96ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2530.07ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2528.28ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2491.90ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2474.51ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2473.58ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2488.20ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2486.72ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2512.00ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2509.54ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2521.92ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2522.46ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2521.83ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2506.72ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2503.68ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2503.29ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2473.07ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2459.79ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2457.12ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2474.86ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2474.72ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2500.31ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2500.41ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2515.96ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2512.84ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2515.40ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2501.28ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2519.06ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2480.41ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2482.96ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2468.03ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2468.46ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2482.73ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2513.93ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2498.40ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2507.70ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2523.49ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2520.67ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2520.10ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2500.24ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2514.16ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2490.70ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2491.22ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2474.85ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2481.33ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2513.82ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2523.92ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2508.97ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2513.90ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2528.55ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2528.06ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2526.65ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2510.92ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2495.66ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2493.96ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2485.28ms, Detection FPS: 0.4, total FPS: 0.4
# Processing video harder_challenge_video.mp4
# 2022-10-30 15:33:38.811599: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-30 15:33:38.813134: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-30 15:33:38.813861: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-30 15:33:38.814644: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-30 15:33:38.815399: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-30 15:33:38.815992: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15401 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# OpenCV: FFMPEG: tag 0x44495658/'XVID' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# Time: 2264.59ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2274.47ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2590.83ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2510.02ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2462.49ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2431.28ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2469.69ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2447.73ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2427.38ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2413.78ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2409.74ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2417.28ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2405.46ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2399.23ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2390.97ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2443.60ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2433.39ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2420.83ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2411.64ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2415.47ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2428.74ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2428.52ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2384.62ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2384.58ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2403.60ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2403.54ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2383.74ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2381.89ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2416.02ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2425.06ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2418.67ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2405.57ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2405.37ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2438.01ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2440.46ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2392.92ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2390.48ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2391.45ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2408.70ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2397.64ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2385.07ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2412.69ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2426.43ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2428.17ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2408.49ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2406.08ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2414.35ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2432.56ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2399.32ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2388.07ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2388.01ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2400.08ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2403.19ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2366.13ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2377.66ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2393.02ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2411.07ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2414.37ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2398.56ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2401.09ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2421.72ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2396.87ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2377.27ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2377.40ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2379.18ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2398.82ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2388.71ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2386.79ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2402.11ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2411.22ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2418.77ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2410.63ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2409.26ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2423.56ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2424.89ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2411.54ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2396.23ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2396.02ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2393.34ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2408.64ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2411.10ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2415.69ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2420.67ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2455.98ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2457.05ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2442.08ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2442.37ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2455.35ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2443.85ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2440.03ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2436.80ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2434.99ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2451.19ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2475.10ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2461.58ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2459.60ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2474.60ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2473.48ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2473.42ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2457.00ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2443.39ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2450.02ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2448.56ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2410.83ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2411.40ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2431.09ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2466.26ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2438.20ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2441.58ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2442.18ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2457.51ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2460.23ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2446.62ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2412.95ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2437.05ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2436.61ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2426.07ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2429.54ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2436.03ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2485.06ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2481.57ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2471.17ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2476.01ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2496.25ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2495.41ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2476.94ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2442.88ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2469.42ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2464.88ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2463.10ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2447.57ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2503.23ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2505.42ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2503.91ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2476.61ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2476.73ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2485.37ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2480.55ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2473.66ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2423.12ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2415.80ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2436.36ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2429.29ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2409.23ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2413.84ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2449.42ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2448.83ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2420.12ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2417.78ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2413.43ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2426.67ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2365.35ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2357.27ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2357.39ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2384.45ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2387.00ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2373.14ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2380.03ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2414.22ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2427.12ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2426.33ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2401.30ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2399.82ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2407.84ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2404.22ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2365.69ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2364.72ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2364.34ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2386.89ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2387.69ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2368.67ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2402.21ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2403.25ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2414.87ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2388.54ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2383.26ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2382.86ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2394.06ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2362.04ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2346.93ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2347.57ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2372.10ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2392.82ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2388.57ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2417.99ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2419.41ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2438.10ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2441.40ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2418.83ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2420.21ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2426.99ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2409.57ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2410.88ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2398.74ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2400.22ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2427.75ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2429.85ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2447.15ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2446.00ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2449.04ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2464.06ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2439.99ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2424.07ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2421.15ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2402.97ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2399.33ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2381.05ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2382.17ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2391.61ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2407.57ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2438.02ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2425.14ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2424.06ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2437.16ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2439.83ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2418.47ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2419.67ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2384.63ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2399.76ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2400.52ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2386.90ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2388.09ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2409.52ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2443.91ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2429.77ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2429.76ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2429.20ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2444.08ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2433.67ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2417.38ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2393.53ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2411.33ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2412.93ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2397.86ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2393.63ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2398.23ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2444.51ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2445.26ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2432.05ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2432.10ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2446.88ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2446.25ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2418.71ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2386.66ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2385.40ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2403.68ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2404.87ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2386.22ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2385.08ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2440.07ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2430.07ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2409.10ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2406.00ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2408.12ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2424.29ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2416.06ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2367.72ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2367.80ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2366.86ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2380.99ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2366.19ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2365.00ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2410.03ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2422.14ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2421.81ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2406.51ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2405.81ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2406.72ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2424.27ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2366.69ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2366.60ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2368.95ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2384.66ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2382.78ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2367.20ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2390.54ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2404.49ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2420.33ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2420.43ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2404.92ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2423.29ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2438.17ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2397.57ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2382.60ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2384.18ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2385.37ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2402.44ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2404.06ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2421.97ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2435.04ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2451.62ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2453.29ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2439.37ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2441.84ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2443.52ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2436.52ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2422.92ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2407.82ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2408.75ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2416.32ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2403.97ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2424.82ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2424.21ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2434.02ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2448.64ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2447.94ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2430.28ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2427.78ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2405.84ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2398.19ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2382.30ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2380.72ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2378.32ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2390.86ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2416.53ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2404.50ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2412.78ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2423.10ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2427.00ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2421.32ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2415.95ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2383.61ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2400.93ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2391.88ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2377.14ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2375.55ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2374.46ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2413.96ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2406.19ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2414.46ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2424.40ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2439.04ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2440.76ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2428.06ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2400.55ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2395.82ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2399.90ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2389.40ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2385.60ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2383.41ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2413.34ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2421.37ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2408.32ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2418.29ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2421.54ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2439.01ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2442.35ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2403.99ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2400.56ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2405.40ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2394.72ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2379.38ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2380.78ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2387.48ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2431.34ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2436.53ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2426.34ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2436.21ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2452.31ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2451.64ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2420.70ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2410.11ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2405.77ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2412.27ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2406.53ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2387.03ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2384.82ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2430.29ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2428.56ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2414.20ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2424.41ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2425.18ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2440.24ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2430.68ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2383.77ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2377.94ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2372.85ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2374.67ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2356.04ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2374.46ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2408.17ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2420.53ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2419.53ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2403.30ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2414.08ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2429.20ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2430.67ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2386.04ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2387.83ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2384.64ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2390.39ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2389.01ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2375.36ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2411.78ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2431.53ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2434.54ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2437.22ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2431.46ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2432.65ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2428.67ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2394.60ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2381.02ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2379.35ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2380.72ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2389.56ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2374.45ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2403.47ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2400.66ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2414.06ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2414.86ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2397.47ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2408.18ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2406.74ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2387.93ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2372.12ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2370.42ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2369.00ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2372.09ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2378.51ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2397.07ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2398.92ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2398.71ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2415.40ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2414.50ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2405.42ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2406.97ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2380.38ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2387.96ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2383.75ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2385.50ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2388.77ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2394.33ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2430.66ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2417.07ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2416.37ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2428.48ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2429.27ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2421.56ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2423.73ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2393.04ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2404.62ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2405.06ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2391.32ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2388.59ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2383.67ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2431.30ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2427.54ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2420.32ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2408.10ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2422.29ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2420.31ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2414.96ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2379.05ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2379.16ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2399.85ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2390.67ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2393.66ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2394.40ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2432.64ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2428.06ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2414.72ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2414.80ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2413.18ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2428.30ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2421.77ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2384.27ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2383.95ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2399.66ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2403.46ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2388.57ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2393.66ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2416.79ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2433.85ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2431.19ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2410.13ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2406.27ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2415.70ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2412.31ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2389.24ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2391.69ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2393.44ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2410.76ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2411.91ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2397.78ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2433.85ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2436.42ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2438.21ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2424.13ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2422.00ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2423.65ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2434.48ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2399.42ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2388.11ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2388.90ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2397.62ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2401.98ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2387.87ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2406.44ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2389.40ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2404.27ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2399.68ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2380.47ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2379.50ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2380.55ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2362.41ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2359.17ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2355.50ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2355.54ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2372.04ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2368.53ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2350.59ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2383.94ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2377.72ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2392.27ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2384.49ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2378.73ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2380.99ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2374.08ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2371.38ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2367.95ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2373.12ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2377.72ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2392.26ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2393.25ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2413.03ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2402.94ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2420.49ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2433.50ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2417.13ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2418.50ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2421.69ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2405.70ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2415.86ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2402.54ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2400.00ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2402.26ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2415.61ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2437.58ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2432.67ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2419.24ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2432.11ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2427.96ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2414.06ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2413.74ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2378.01ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2394.95ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2389.01ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2373.29ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2372.71ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2388.90ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2422.05ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2409.27ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2398.85ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2398.62ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2417.00ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2415.46ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2400.33ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2369.51ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2384.94ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2397.35ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2381.71ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2384.04ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2384.29ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2428.77ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2429.57ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2411.34ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2400.70ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2419.28ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2420.23ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2407.13ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2372.48ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2368.82ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2383.93ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2391.31ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2373.74ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2374.76ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2419.39ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2430.89ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2415.66ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2407.06ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2407.42ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2420.99ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2421.20ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2375.37ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2378.45ms, Detection FPS: 0.4, total FPS: 0.4
# ...
# Time: 2493.00ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2488.43ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2489.06ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2479.13ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2475.84ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2460.32ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2459.86ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2441.62ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2439.58ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2419.99ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2420.14ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2441.65ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2468.36ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2465.42ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2456.58ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2460.85ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2469.06ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2460.93ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2445.66ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2445.84ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2429.83ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2430.66ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2416.46ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2416.03ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2431.89ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2468.33ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2469.34ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2456.29ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2457.75ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2482.11ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2482.99ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2459.17ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2433.20ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2444.97ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2447.32ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2443.76ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2433.56ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2433.14ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2491.92ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2494.16ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2479.15ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2479.17ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2492.25ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2494.45ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2479.00ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2442.16ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2454.63ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2449.97ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2450.31ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2427.87ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2434.04ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2476.61ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2488.72ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2474.66ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2474.40ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2492.96ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2494.41ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2494.79ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2437.40ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2436.91ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2446.58ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2444.90ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2430.19ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2462.54ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2477.63ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2488.05ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2474.48ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2475.02ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2491.28ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2490.81ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2482.25ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2439.35ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2428.40ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2440.56ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2439.30ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2420.92ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2455.85ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2486.63ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2485.80ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2494.90ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2483.15ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2498.67ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2499.67ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2465.47ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2451.54ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2443.21ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2460.33ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2461.94ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2475.48ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2474.04ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2489.31ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2489.72ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2488.63ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2484.29ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2492.10ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2497.54ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2461.81ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2428.74ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2429.91ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2437.64ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2438.91ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2457.27ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2459.15ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2474.42ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2473.45ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2473.12ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2457.13ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2467.00ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2452.44ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2452.17ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2435.75ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2437.04ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2451.39ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2446.28ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2463.87ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2458.92ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2465.37ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2474.49ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2475.63ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2457.75ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2467.60ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2447.73ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2442.92ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2429.48ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2429.87ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2436.79ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2482.89ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2471.85ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2454.33ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2454.61ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2472.94ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2470.46ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2457.20ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2453.20ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2452.52ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2454.18ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2447.56ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2438.62ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2436.16ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2481.53ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2470.44ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2455.89ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2456.47ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2468.71ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2467.54ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2460.15ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2411.94ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2411.81ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2438.07ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2439.16ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2421.90ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2423.46ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2472.74ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2471.99ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2448.44ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2456.29ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2471.50ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2473.68ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2474.50ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2429.77ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2431.04ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2453.31ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2455.59ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2441.32ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2465.73ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2481.84ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2481.32ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2481.53ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2457.04ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2457.96ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2466.80ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2465.37ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2413.81ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2412.43ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2446.62ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2447.38ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2433.65ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2463.93ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2480.77ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2480.66ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2480.27ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2459.17ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2460.52ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2477.81ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2453.69ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2437.49ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2440.58ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2455.98ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2457.24ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2467.71ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2484.97ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2498.69ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2501.31ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2504.18ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2470.07ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2460.94ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2475.51ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2445.30ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2428.15ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2430.32ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2445.90ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2446.06ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2480.19ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2474.86ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2487.51ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2488.71ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2487.54ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2473.82ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2472.02ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2476.91ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2452.02ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2438.81ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2437.01ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2446.92ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2450.98ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2481.91ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2476.14ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2476.44ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2499.01ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2499.87ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2483.51ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2483.26ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2479.47ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2470.43ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2458.22ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2455.39ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2466.48ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2496.89ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2497.09ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2481.59ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2489.76ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2506.60ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2507.03ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2496.55ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2493.31ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2479.25ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2471.11ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2470.00ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2446.44ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2442.64ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2489.32ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2488.78ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2455.65ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2454.53ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2476.64ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2477.13ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2467.08ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2437.74ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2453.24ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2454.43ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2445.40ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2427.50ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2424.85ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2467.58ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2463.51ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2444.10ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2440.78ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2462.23ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2463.05ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2463.26ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2417.71ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2415.87ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2431.81ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2429.97ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2406.71ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2403.92ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2448.65ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2448.27ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2431.64ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2427.49ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2428.66ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2466.48ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2470.03ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2424.27ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2425.71ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2442.73ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2443.09ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2419.60ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2442.71ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2462.89ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2461.86ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2464.19ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2449.10ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2446.56ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2460.30ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2470.78ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2421.91ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2417.70ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2427.79ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2436.30ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2434.35ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2430.55ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2428.93ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2446.94ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2447.85ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2429.90ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2432.37ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2451.80ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2429.00ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2415.13ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2415.44ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2411.35ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2423.10ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2423.37ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2441.56ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2431.96ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2447.90ms, Detection FPS: 0.4, total FPS: 0.4
